# %%
"""


"""

# %% [markdown]
# ### Comentarios

# %% [markdown]
# # Variables

# %% [markdown]
# ## Strings

# %%
nombre= 'Alan Carrillo'

# %%
type(nombre)
# Out:
# str

# %%
nombre[2]
# Out:
# 'a'
